# %%
import pandas as pd
A = pd.read_csv("C:/Users/HP/Desktop/ETLHive/Project 2/zomato.csv",encoding="latin-1")
A.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
A.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
#A.info()
A.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
A.Cuisines = A.Cuisines.fillna(A.Cuisines.mode()[0])

# %%
#A.isna().sum()
#A.isna().any()
A.shape
# Out:
# (9551, 21)

# %%
B = pd.read_excel("C:/Users/HP/Desktop/ETLHive/Project 2/Country-Code.xlsx")
B.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
#X = pd.merge(A,B,left_on="Country Code",right_on="Country Code",how='left')
X = pd.merge(A,B,on="Country Code",how='left')
X.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
X.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
Country_name = X.Country.value_counts().index

# %%
Country_val = X.Country.value_counts().values

# %%
#pie chart of top 3 countries using zomato
import matplotlib.pyplot as plt

plt.pie(Country_val[:3],labels=Country_name[:3], autopct='%1.2f%%')
plt.show()

# %% [markdown]
# Oservation : 1.Zomato Maximum records or transaction are from India After that UAS and then United Kingdom.

# %%
ratings = X.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:"rating count"})
ratings
# Out:
#     Aggregate rating Rating color Rating text  rating count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# Observations-
# 1.When Rating is between 4.5 to 4.9 = Excellent
#
# 2.When Rating is between 4.0 to 4.4 = Very Good
#
# 3.When Rating is between 3.5 to 3.9 = Good
#
# 4.When Rating is between 2.5 to 3.4 = Average
#
# 5.When Rating is between 1.8 to 2.4 = Poor

# %%
import seaborn as sb
sb.barplot(x=ratings['Aggregate rating'],y=ratings['rating count'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='rating count'>

# %% [markdown]
# Observations-
# 1.not rated count is very high
# 2.Maximum number rating are between 2.5 to 3.4

# %%
X[X['Aggregate rating']==0].groupby('Country').size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %%
X.groupby(['Aggregate rating','Country']).size().reset_index().head(4)
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3

# %% [markdown]
# Observation-
# 1.Maximum number of zero rating are from Indian Customers.

# %%
X[X['Has Online delivery']=="Yes"].groupby(['Country', 'Has Online delivery']).size().reset_index()
# Out:
#   Country Has Online delivery     0
# 0   India                 Yes  2423
# 1     UAE                 Yes    28

# %%
X[X['Has Online delivery']=="Yes"].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %% [markdown]
# Observation-
# 1.Online delivery are available in India and UAE

# %%
#create a pie chart top 5 cities distribution 
X.City.value_counts().index
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad',
#        'Bhubaneshwar', 'Amritsar', 'Ahmedabad', 'Lucknow', 'Guwahati',
#        ...
#        'Ojo Caliente', 'Montville', 'Monroe', 'Miller', 'Middleton Beach',
#        'Panchkula', 'Mc Millan', 'Mayfield', 'Macedon', 'Vineland Station'],
#       dtype='object', length=141)

# %%
plt.axis("equal")
city_val = X.City.value_counts().values
city_index =X.City.value_counts().index
plt.pie(city_val[:5],labels=city_index[:5], autopct='%1.2f%%',radius=1.5)
plt.show()
